# %% [markdown]
# # Joining all the database to have all the data needed for the ML alog

# %% [markdown]
# ## Importing all the different database

# %%
import pandas as pd
import numpy as np

# %%
df_SMB = pd.read_csv('/home/colili/Documents/PhD/project_john/DataFrame_produced/df_SMB.csv')
df_width = pd.read_csv('/home/colili/Documents/PhD/project_john/DataFrame_produced/df_width.csv')
df_slope = pd.read_csv('/home/colili/Documents/PhD/project_john/DataFrame_produced/df_bed_surfe_thick_slope.csv')
df_main = pd.read_csv('/home/colili/Documents/PhD/project_john/DataFrame_produced/df_bed_surf_elev.csv')

# %% [markdown]
# ## Group them by RGIId

# %%
df_SMB.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           rgiid              x             y  \
# 0           0             0  RGI60-07.00001  552858.197838  8.514877e+06
# 1           1             1  RGI60-07.00001  552837.209663  8.514876e+06
# 2           2             2  RGI60-07.00001  552816.221488  8.514875e+06
# 3           3             3  RGI60-07.00001  552795.233313  8.514875e+06
# 4           4             4  RGI60-07.00001  552774.245139  8.514874e+06
#
#    Surge   BgnDate  EndDate   CenLon   CenLat  ...  Linkages  Name  \
# 0      0  20080901 -9999999  17.0347  76.7052  ...         9   NaN
# 1      0  20080901 -9999999  17.0347  76.7052  ...         9   NaN
# 2      0  20080901 -9999999  17.0347  76.7052  ...         9   NaN
# 3      0  20080901 -9999999  17.0347  76.7052  ...         9   NaN
# 4      0  20080901 -9999999  17.0347  76.7052  ...         9   NaN
#
#    check_geom  geometry        bed  thickness  surface_elevation  \
# 0         NaN       NaN  401.83295    4.16705              406.0
# 1         NaN       NaN  401.83295    4.16705              406.0
# 2         NaN       NaN  401.83295    4.16705              406.0
# 3         NaN       NaN  401.83295    4.16705              406.0
# 4         NaN       NaN  401.83295    4.16705              406.0
#
#                                    points            closest      CMB
# 0   (552858.1978384765, 8514876.79335722)  (552490, 8515290) -0.83576
# 1  (552837.2096627597, 8514876.067688115)  (552490, 8515290) -0.83576
# 2  (552816.2214876048, 8514875.342019048)  (552490, 8515290) -0.83576
# 3  (552795.2333130117, 8514874.616350023)  (552490, 8515290) -0.83576
# 4  (552774.2451389803, 8514873.890681034)  (552490, 8515290) -0.83576
#
# [5 rows x 31 columns]

# %%
df_width.head()
# Out:
#    Unnamed: 0           RGIId       X       Y  Widths (m)
# 0           0  RGI60-07.00001  2163.0  2667.0  127.068879
# 1           1  RGI60-07.00001  2163.0  2625.0  143.420355
# 2           2  RGI60-07.00001  2163.0  2583.0  180.607849
# 3           3  RGI60-07.00001  2163.0  2541.0  221.224095
# 4           4  RGI60-07.00001  2163.0  2499.0  270.773829

# %%
df_slope.head()
# Out:
#    Unnamed: 0  window_length  bed_slope  thick_mean  surf_slope  window_id  \
# 0           0      67.882756   0.111799   28.124966    0.029454          0
# 1           1      75.895233   0.094299   33.024520    0.039508          1
# 2           2      72.000544   0.171784   35.359420    0.165147          2
# 3           3      48.000365   0.000000   35.605247    0.000000          3
# 4           4      72.000551   0.000000   35.146767    0.000000          4
#
#             rgiid
# 0  RGI60-07.00004
# 1  RGI60-07.00004
# 2  RGI60-07.00004
# 3  RGI60-07.00004
# 4  RGI60-07.00004

# %%
df_main.head()
# Out:
#    Unnamed: 0           rgiid              x             y  Surge   BgnDate  \
# 0           0  RGI60-07.00001  552858.197838  8.514877e+06      0  20080901
# 1           1  RGI60-07.00001  552837.209663  8.514876e+06      0  20080901
# 2           2  RGI60-07.00001  552816.221488  8.514875e+06      0  20080901
# 3           3  RGI60-07.00001  552795.233313  8.514875e+06      0  20080901
# 4           4  RGI60-07.00001  552774.245139  8.514874e+06      0  20080901
#
#    EndDate   CenLon   CenLat   Area  ...  Connect  Form  TermType  Linkages  \
# 0 -9999999  17.0347  76.7052  0.597  ...        0     0         0         9
# 1 -9999999  17.0347  76.7052  0.597  ...        0     0         0         9
# 2 -9999999  17.0347  76.7052  0.597  ...        0     0         0         9
# 3 -9999999  17.0347  76.7052  0.597  ...        0     0         0         9
# 4 -9999999  17.0347  76.7052  0.597  ...        0     0         0         9
#
#    Name  check_geom  geometry        bed  thickness  surface_elevation
# 0   NaN         NaN       NaN  401.83295    4.16705              406.0
# 1   NaN         NaN       NaN  401.83295    4.16705              406.0
# 2   NaN         NaN       NaN  401.83295    4.16705              406.0
# 3   NaN         NaN       NaN  401.83295    4.16705              406.0
# 4   NaN         NaN       NaN  401.83295    4.16705              406.0
#
# [5 rows x 27 columns]
